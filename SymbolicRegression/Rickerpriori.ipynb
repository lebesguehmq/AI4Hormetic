# %% [markdown]
# ### seed(41)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sympy import expand_power_exp
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_RickerPriori/RickerModel/RickerDS2Bootstrap-results/bootstrap_001_seed_41/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
          "exp",
#         "sin",
#          "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="score",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
          "exp": 1
#         "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)

x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {expand_power_exp(model.sympy()).evalf()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.359e-04  0.000e+00  y = 0.12056
# 5           4.570e-05  6.582e-01  y = (x₀ * -0.0025589) + 0.19668
# 6           2.830e-05  4.791e-01  y = exp(x₀ * -0.16526) + 0.10011
# 8           2.352e-07  2.395e+00  y = exp((-0.087282 * x₀) + -1.167) + 0.088346
# 10          1.420e-07  2.523e-01  y = (exp((x₀ * -0.086197) + -1.0299) + 0.10102) * 0.8679
# 12          1.393e-07  9.723e-03  y = (exp(((x₀ - 0.014357) * -0.086197) + -1.0299) + 0.1010...
#                                       2) * 0.8679
# 15          1.366e-07  6.365e-03  y = (exp(((x₀ - exp(x₀ * -0.24066)) * -0.086197) + -1.0299...
# ...

# %%
fx_fit = 0.08834624 + 0.311300467428064*np.exp(-0.08728157*x)

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(42)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sympy import expand_power_exp
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_RickerPriori/RickerModel/RickerDS2Bootstrap-results/bootstrap_002_seed_42/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
          "exp",
#         "sin",
#          "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="score",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
          "exp": 1
#         "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {expand_power_exp(model.sympy()).evalf()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.716e-04  0.000e+00  y = 0.11892
# 5           3.993e-05  6.653e-01  y = (x₀ * -0.0024341) - -0.19253
# 7           3.992e-05  1.028e-04  y = (x₀ * -1.0024) + (x₀ + 0.19253)
# 8           2.638e-05  4.145e-01  y = exp((x₀ * -0.022516) + -1.4783)
# 10          4.839e-07  1.999e+00  y = exp((x₀ * -0.084575) + -1.2327) + 0.087956
# 12          4.644e-07  2.054e-02  y = exp((-0.084575 * (-0.037781 + x₀)) + -1.2327) + 0.0879...
#                                       56
# 17          3.747e-07  4.296e-02  y = exp((x₀ * -0.084724) + -1.2327) + (exp(8.5228 - x₀) + ...
# ...

# %%
fx_fit = 0.29149153880815*np.exp(x*(-0.08457468)) + 0.08795607

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(43)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sympy import expand_power_exp
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_RickerPriori/RickerModel/RickerDS2Bootstrap-results/bootstrap_003_seed_43/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
          "exp",
#         "sin",
#          "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="score",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
          "exp": 1
#         "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {expand_power_exp(model.sympy()).evalf()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.577e-04  0.000e+00  y = 0.12012
# 5           4.548e-05  7.033e-01  y = 0.20242 - (x₀ * 0.0027444)
# 7           4.547e-05  7.412e-05  y = (0.20241 - x₀) + (x₀ * 0.99726)
# 9           4.546e-05  7.061e-05  y = (x₀ + x₀) + (0.20241 - (x₀ * 2.0027))
# 10          5.580e-07  4.400e+00  y = exp(-1.3041 - (x₀ * 0.074588)) + 0.08236
# 12          5.286e-07  2.708e-02  y = exp(-1.2961 - ((x₀ + -0.11417) * 0.075749)) + 0.082818
# 14          5.280e-07  5.315e-04  y = exp(-1.2961 - ((x₀ + (0.082821 - 0.20006)) * 0.075749)...
#                                       ) + 0.082818
# ...

# %%
fx_fit = 0.08235962 + 0.271403672496031*np.exp(-0.07458765*x)

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(44)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sympy import expand_power_exp
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_RickerPriori/RickerModel/RickerDS2Bootstrap-results/bootstrap_004_seed_44/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
          "exp",
#         "sin",
#          "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="score",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
          "exp": 3
#         "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {expand_power_exp(model.sympy()).evalf()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.798e-04  0.000e+00  y = 0.1193
# 5           4.342e-05  6.877e-01  y = (x₀ * -0.0026057) + 0.19785
# 7           4.341e-05  7.195e-05  y = x₀ + (0.19783 - (x₀ * 1.0026))
# 8           2.601e-05  5.124e-01  y = exp(-1.4388 - (x₀ * 0.02364))
# 10          5.947e-07  1.889e+00  y = exp(-1.3212 - (x₀ * 0.074965)) + 0.083399
# 14          7.148e-08  5.297e-01  y = ((exp(-2.8553 - (x₀ * 0.1909)) + -0.0010616) * x₀) + 0...
#                                       .1378
# 18          5.647e-08  5.893e-02  y = ((exp(-3.1119 - ((x₀ + -1.1529) * 0.1913)) + -0.001101...
# ...

# %%
fx_fit = 0.083398506 + 0.266817813480822*np.exp(-0.07496534*x)

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(45)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sympy import expand_power_exp
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_RickerPriori/RickerModel/RickerDS2Bootstrap-results/bootstrap_005_seed_45/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
          "exp",
#         "sin",
#          "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="score",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
          "exp": 3
#         "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {expand_power_exp(model.sympy()).evalf()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.485e-04  0.000e+00  y = 0.12031
# 5           4.672e-05  6.576e-01  y = (x₀ * -0.0025413) + 0.19642
# 7           4.671e-05  8.056e-05  y = x₀ + ((x₀ * -1.0025) + 0.19642)
# 8           2.645e-05  5.689e-01  y = exp(-1.5053 - (x₀ * 0.021189))
# 10          1.040e-06  1.618e+00  y = exp((x₀ * -0.093773) + -1.1207) - -0.091114
# 14          6.765e-08  6.832e-01  y = 0.42006 * ((exp(x₀ * -0.14196) + (x₀ * -0.0024083)) - ...
#                                       -0.32564)
# 16          4.660e-08  1.864e-01  y = (exp((x₀ + 0.081566) * -0.14196) + ((x₀ * -0.0024083) ...
# ...

# %%
fx_fit =0.326061162559426*np.exp(x*(-0.093773074)) + 0.091114156

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(46)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sympy import expand_power_exp
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_RickerPriori/RickerModel/RickerDS2Bootstrap-results/bootstrap_006_seed_46/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
          "exp",
#         "sin",
#          "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="score",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
          "exp": 1
#         "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {expand_power_exp(model.sympy()).evalf()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.678e-04  0.000e+00  y = 0.12101
# 5           5.011e-05  6.475e-01  y = (x₀ * -0.0025495) + 0.19688
# 7           5.010e-05  7.621e-05  y = x₀ + ((x₀ * -1.0026) + 0.19689)
# 8           3.398e-05  3.884e-01  y = exp(x₀ * -0.1703) - -0.10121
# 10          8.538e-07  1.842e+00  y = exp((x₀ * -0.081647) + -1.2827) - -0.087907
# 12          6.137e-07  1.651e-01  y = exp(((x₀ + -0.17517) * -0.081804) + -1.2827) - -0.0877...
#                                       11
# 14          1.793e-08  1.767e+00  y = (exp((x₀ * -0.12468) + -1.0069) + (x₀ * -0.00078149)) ...
# ...

# %%
fx_fit = 0.277297400701923*np.exp(x*(-0.08164671)) + 0.08790696

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(47)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sympy import expand_power_exp
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_RickerPriori/RickerModel/RickerDS2Bootstrap-results/bootstrap_007_seed_47/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
          "exp",
#         "sin",
#          "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="score",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
          "exp": 1
#         "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {expand_power_exp(model.sympy()).evalf()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.422e-04  0.000e+00  y = 0.12123
# 5           4.896e-05  6.797e-01  y = (x₀ * -0.0026732) + 0.20058
# 7           4.895e-05  7.400e-05  y = x₀ + ((x₀ * -1.0027) + 0.20058)
# 8           2.591e-05  6.360e-01  y = exp((x₀ * -0.022766) + -1.4601)
# 10          1.133e-06  1.565e+00  y = exp((x₀ * -0.077498) + -1.3111) + 0.085263
# 12          8.705e-07  1.318e-01  y = exp(((x₀ - 0.63333) * -0.080411) + -1.3112) + 0.085734
# 14          3.558e-07  4.473e-01  y = (exp((x₀ + 2.8365) * -0.18381) + 0.15534) + (x₀ * -0.0...
#                                       014766)
# ...

# %%
fx_fit = 0.269531449421476*np.exp(x*(-0.07749826)) + 0.085262895

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(48)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sympy import expand_power_exp
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_RickerPriori/RickerModel/RickerDS2Bootstrap-results/bootstrap_008_seed_48/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
          "exp",
#         "sin",
#          "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="score",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
          "exp": 1
#         "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {expand_power_exp(model.sympy()).evalf()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.931e-04  0.000e+00  y = 0.12135
# 5           5.674e-05  6.594e-01  y = (x₀ * -0.0026838) + 0.2006
# 7           5.673e-05  6.825e-05  y = ((x₀ * -1.0027) + 0.20062) + x₀
# 8           3.005e-05  6.355e-01  y = exp(x₀ * -0.022745) * 0.2314
# 10          3.025e-06  1.148e+00  y = (exp(x₀ * -0.087274) - -0.27694) * 0.31037
# 12          1.120e-06  4.970e-01  y = (exp((x₀ + -10.603) * -0.081131) * 0.12286) - -0.08483...
#                                       9
# 14          1.120e-06  5.731e-05  y = (exp(((x₀ + -20.09) * -0.081028) + 0.71875) * 0.027757...
# ...

# %%
fx_fit = 0.31037205*np.exp(x*(-0.0872738)) + 0.085954553468379

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(49)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sympy import expand_power_exp
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_RickerPriori/RickerModel/RickerDS2Bootstrap-results/bootstrap_009_seed_49/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
          "exp",
#         "sin",
#          "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="score",
    complexity_of_operators={
# # #         "sin": 3, 
#         "cos": 3,
          "exp": 1
#         "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {expand_power_exp(model.sympy()).evalf()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.084e-04  0.000e+00  y = 0.12178
# 5           5.703e-05  6.298e-01  y = (x₀ * -0.002561) + 0.1976
# 7           5.702e-05  6.944e-05  y = (x₀ * 0.99744) - (x₀ + -0.1976)
# 8           3.565e-05  4.698e-01  y = exp(x₀ * -0.17157) + 0.10135
# 9           4.130e-06  2.155e+00  y = (((x₀ * 0.00010502) - 0.0086328) * x₀) + 0.27488
# 10          3.862e-07  2.370e+00  y = (exp(x₀ * -0.088996) * 0.30954) + 0.089749
# 12          3.399e-07  6.386e-02  y = (exp((x₀ + 1.4362) * -0.084791) + 0.26559) * 0.33189
# ...

# %%
fx_fit = 0.3095369*np.exp(x*(-0.08899562)) + 0.08974917

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(50)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sympy import expand_power_exp
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_RickerPriori/RickerModel/RickerDS2Bootstrap-results/bootstrap_010_seed_50/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
          "exp",
#         "sin",
#          "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="score",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
          "exp": 1
#         "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {expand_power_exp(model.sympy()).evalf()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.530e-04  0.000e+00  y = 0.1192
# 5           4.498e-05  6.688e-01  y = (x₀ * -0.0025004) + 0.19497
# 7           4.498e-05  6.643e-05  y = x₀ - ((x₀ * 1.0025) - 0.19496)
# 8           3.799e-05  1.688e-01  y = exp(x₀ * -0.16996) + 0.1002
# 10          1.479e-06  1.623e+00  y = exp((x₀ * -0.092155) + -1.1399) + 0.089984
# 12          7.582e-07  3.343e-01  y = (exp((x₀ * -0.083778) + -1.8366) + 0.048418) * 1.8104
# 14          6.841e-07  5.138e-02  y = (exp(((x₀ - 0.098151) * -0.083923) + -1.8366) + 0.0481...
#                                       72) * 1.8104
# ...

# %%
fx_fit = 0.319863447763745*np.exp(x*(-0.092155494)) + 0.089983985

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()
