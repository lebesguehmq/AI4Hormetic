# %% [markdown]
# ### seed(41)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_BHpriori/BHmodel/DS2Bootstrap-results/bootstrap_001_seed_41/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
#           "exp",
#         "sin",
         "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="best",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
# #           "exp": 1
        "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {model.sympy()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.625e-03  0.000e+00  y = 0.58374
# 5           1.004e-03  5.068e-01  y = (x₀ * 0.0076836) - -0.36694
# 7           4.943e-04  3.544e-01  y = (x₀ * (x₀ * 0.00013544)) - -0.46072
# 9           9.553e-05  8.218e-01  y = ((-0.01542 - (x₀ * -0.0003954)) * x₀) - -0.65971
# 11          9.553e-05  1.788e-07  y = ((0.014962 - (x₀ * 0.00039537)) * (1.1567 - x₀)) - -0....
#                                       64239
# 13          9.551e-05  6.703e-05  y = (x₀ + 0.65971) - ((x₀ * 1.0154) - (x₀ * (x₀ * 0.000395...
#                                       41)))
# 15          1.036e-05  1.111e+00  y = ((((x₀ * 0.016077) * x₀) - x₀) * (0.042593 - (x₀ * 0.0...
#                                       0070394))) - -0.88831
# 17          1.021e-05  7.039e-03  y = ((0.028345 - (x₀ * 0.00053198)) * ((x₀ * ((x₀ * x₀) * ...
#                                       0.00035759)) - x₀)) - -0.80504
# 18          7.671e-06  2.860e-01  y = (((0.75349 - (square(x₀) * -0.016313)) - x₀) * (0.0443...
#                                       13 - (x₀ * 0.00073962))) - -0.87628
# 19          6.247e-06  2.055e-01  y = ((0.032235 - (x₀ * 0.00069043)) * (((x₀ * ((x₀ * 0.000...
#                                       32548) * x₀)) - x₀) - -3.2896)) - -0.75893
# 24          6.218e-06  9.128e-04  y = ((((0.089471 - ((x₀ - x₀) + -1.1759)) - (square(x₀) * ...
#                                       -0.016616)) - x₀) * (0.045321 - (x₀ * 0.00075953))) - -0.8...
#                                       6458
# 25          5.680e-06  9.049e-02  y = ((0.031812 - (x₀ * 0.00073759)) * (((((x₀ * (x₀ - -2.9...
#                                       101)) * 0.00029992) * (x₀ - (x₀ * 0.12252))) - x₀) - -4.32...
#                                       6)) - -0.7262
# 29          5.680e-06  4.619e-07  y = ((0.031812 - (x₀ * 0.00073759)) * ((((x₀ * ((x₀ + ((x₀...
#                                        - x₀) - -2.9101)) * 0.00029992)) * (x₀ - (x₀ * 0.12252)))...
#                                        - x₀) - -4.326)) - -0.7262
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Model for 'f': PySRRegressor.equations_ = [
# 	    pick         score                                           equation  \
# 	0         0.000000e+00                                         0.58374065
# 	1         5.068000e-01                  (x0 * 0.0076835593) - -0.36694407
# 	2         3.544411e-01          (x0 * (x0 * 0.00013544058)) - -0.46072465
# 	3         8.218454e-01  ((-0.015420358 - (x0 * -0.00039539716)) * x0) ...
# 	4         2.093682e-07  ((0.014961797 - (x0 * 0.00039537475)) * (1.156...
# 	5         6.703373e-05  (x0 + 0.65971273) - ((x0 * 1.015421) - (x0 * (...
# 	6         1.110828e+00  ((((x0 * 0.016077163) * x0) - x0) * (0.0425932...
# 	7         7.039312e-03  ((0.028345456 - (x0 * 0.0005319826)) * ((x0 * ...
# 	8   >>>>  2.860321e-01  (((0.753491 - (square(x0) * -0.016313486)) - x...
# 	9         2.054502e-01  ((0.032235097 - (x0 * 0.00069043133)) * (((x0 ...
# 	10        9.128113e-04  ((((0.08947093 - ((x0 - x0) + -1.1759492)) - (...
# 	11        9.049218e-02  ((0.031811725 - (x0 * 0.0007375878)) * (((((x0...
# 	12        4.577312e-07  ((0.031811725 - (x0 * 0.0007375878)) * ((((x0 ...
#
# 	        loss  complexity
# 	0   0.007625           1
# 	1   0.001004           5
# 	2   0.000494           7
# 	3   0.000096           9
# 	4   0.000096          11
# 	5   0.000096          13
# 	6   0.000010          15
# 	7   0.000010          17
# 	8   0.000008          18
# 	9   0.000006          19
# 	10  0.000006          24
# 	11  0.000006          25
# 	12  0.000006          29
# ]
# Model SymPy for 'f': (0.04431277 - 0.00073962274*x0)*(-(-0.016313486)*x0**2 - x0 + 0.753491) - 1*(-0.8762777)
# Latex Equation for 'f': \left(0.0443 - x_{0} \cdot 0.000740\right) \left(- \left(-0.0163\right) x_{0}^{2} - x_{0} + 0.754\right) - -0.876
#   - outputs\20260724_171822_RRts07\hall_of_fame.csv

# %%
fx_fit = (0.04431277 - 0.00073962274*x)*(-(-0.016313486)*x**2 - x + 0.753491) - 1*(-0.8762777)

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(42)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_BHpriori/BHmodel/DS2Bootstrap-results/bootstrap_002_seed_42/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
#           "exp",
#         "sin",
         "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="best",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
# #           "exp": 1
        "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {model.sympy()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.103e-03  0.000e+00  y = 0.57939
# 5           8.592e-04  5.281e-01  y = (x₀ * 0.0074656) + 0.36705
# 7           4.100e-04  3.700e-01  y = ((x₀ * x₀) * 0.00013122) + 0.45853
# 8           4.100e-04  5.960e-08  y = (square(x₀) * 0.00013122) + 0.45853
# 9           7.862e-05  1.651e+00  y = (((x₀ * 0.00037154) + -0.014259) * x₀) - -0.64276
# 11          7.862e-05  3.278e-07  y = (x₀ * (((x₀ + 1.3904) * 0.00037151) + -0.014774)) - -0...
#                                       .64274
# 13          7.862e-05  9.447e-06  y = (x₀ * ((x₀ * 0.00037148) + -0.26883)) - ((x₀ * -0.2545...
#                                       8) + -0.64271)
# 15          7.862e-05  6.557e-06  y = ((x₀ * ((x₀ * 0.00037149) + -0.31125)) - ((x₀ + 0.3702...
#                                       9) * -0.29699)) + 0.53275
# 17          7.862e-05  7.927e-06  y = ((x₀ * (((x₀ - 0.0059261) * 0.00037156) + -0.36341)) -...
#                                        ((x₀ + 0.25246) * -0.34915)) + 0.55463
# 26          5.109e-05  4.789e-02  y = (x₀ * (((x₀ + ((0.15142 - ((square(x₀ + (x₀ - 0.012776...
#                                       )) - -0.63551) * 0.001308)) + -0.014772)) * 0.00066316) + ...
#                                       -0.021862)) - -0.69991
# 28          3.334e-05  2.134e-01  y = (x₀ * (((x₀ + (0.53583 - ((((square((x₀ + x₀) - -0.597...
#                                       8) * -0.029836) - x₀) * -0.050557) + -0.023912))) * 0.0009...
#                                       0209) + -0.028145)) - -0.75737
# 30          4.745e-06  9.748e-01  y = (x₀ * ((((x₀ + 0.61694) - ((((square((x₀ + x₀) - -0.45...
#                                       451) + -0.096048) * -0.040387) - (x₀ + -0.020899)) * -0.04...
#                                       9784)) * 0.0015266) + -0.044529)) - -0.89017
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Model for 'f': PySRRegressor.equations_ = [
# 	    pick         score                                           equation  \
# 	0         0.000000e+00                                          0.5793911
# 	1         5.280696e-01                   (x0 * 0.0074655726) + 0.36704582
# 	2         3.699645e-01            ((x0 * x0) * 0.00013122466) + 0.4585253
# 	3         9.756823e-08           (square(x0) * 0.00013122438) + 0.4585255
# 	4         1.651464e+00  (((x0 * 0.00037153994) + -0.014259259) * x0) -...
# 	5         3.179877e-07  (x0 * (((x0 + 1.3904103) * 0.00037151438) + -0...
# 	6         9.437967e-06  (x0 * ((x0 * 0.00037147856) + -0.26883432)) - ...
# 	7         6.588875e-06  ((x0 * ((x0 * 0.00037149066) + -0.3112494)) - ...
# 	8         7.886412e-06  ((x0 * (((x0 - 0.0059260577) * 0.00037156054) ...
# 	9         4.788675e-02  (x0 * (((x0 + ((0.15141657 - ((square(x0 + (x0...
# 	10        2.134067e-01  (x0 * (((x0 + (0.5358291 - ((((square((x0 + x0...
# 	11  >>>>  9.747928e-01  (x0 * ((((x0 + 0.61694115) - ((((square((x0 + ...
#
# 	        loss  complexity
# 	0   0.007103           1
# 	1   0.000859           5
# 	2   0.000410           7
# 	3   0.000410           8
# 	4   0.000079           9
# 	5   0.000079          11
# 	6   0.000079          13
# 	7   0.000079          15
# 	8   0.000079          17
# 	9   0.000051          26
# 	10  0.000033          28
# 	11  0.000005          30
# ]
# Model SymPy for 'f': x0*((x0 - (-0.04978357)*(-(x0 - 0.020898726) + ((x0 + x0 - 1*(-0.4545056))**2 - 0.09604789)*(-0.040386837)) + 0.61694115)*0.0015265876 - 0.04452931) - 1*(-0.8901668)
# Latex Equation for 'f': x_{0} \left(\left(x_{0} - \left(- (x_{0} - 0.0209) + \left(\left(x_{0} + x_{0} - -0.455\right)^{2} - 0.0961\right) \left(-0.0404\right)\right) \left(-0.0498\right) + 0.617\right) 0.00153 - 0.0445\right) - -0.890
#   - outputs\20260724_180204_iOMNOi\hall_of_fame.csv

# %%
fx_fit = x*((x - (-0.04978357)*(-(x - 0.020898726) + ((x + x - 1*(-0.4545056))**2 - 0.09604789)*(-0.040386837)) + 0.61694115)*0.0015265876 - 0.04452931) - 1*(-0.8901668)

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(43)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_BHpriori/BHmodel/DS2Bootstrap-results/bootstrap_003_seed_43/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
#           "exp",
#         "sin",
         "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="best",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
# #           "exp": 1
        "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {model.sympy()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.184e-03  0.000e+00  y = 0.57395
# 5           5.168e-04  5.228e-01  y = (x₀ * 0.0057892) + 0.40779
# 7           2.548e-04  3.536e-01  y = ((x₀ * x₀) * 0.00010323) + 0.47762
# 9           6.342e-05  6.953e-01  y = (x₀ * ((x₀ * 0.0002908) + -0.010969)) + 0.61742
# 11          6.328e-05  1.157e-03  y = (x₀ * ((x₀ * -0.99971) + (x₀ + -0.010926))) + 0.61689
# 14          1.178e-05  5.605e-01  y = ((x₀ * square(12.129 - (x₀ * 0.20494))) * -0.00020715)...
#                                        + 0.77546
# 16          9.807e-06  9.149e-02  y = (square((x₀ * 0.20781) - 12.129) * ((x₀ + -0.67913) * ...
#                                       -0.00021381)) + 0.77043
# 23          2.244e-06  2.107e-01  y = (x₀ * ((x₀ * 0.0014503) + (x₀ * (x₀ * -1.3516e-05)))) ...
#                                       + ((x₀ - (x₀ * 0.17095)) + ((x₀ * -0.87103) + 0.87266))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Model for 'f': PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                          0.5739539
# 	1        0.522830                    (x0 * 0.005789187) + 0.40779194
# 	2        0.353601            ((x0 * x0) * 0.00010322619) + 0.4776203
# 	3        0.695328  (x0 * ((x0 * 0.00029080163) + -0.010969404)) +...
# 	4        0.001157  (x0 * ((x0 * -0.99970996) + (x0 + -0.010926451...
# 	5        0.560476  ((x0 * square(12.129296 - (x0 * 0.20494312))) ...
# 	6        0.091485  (square((x0 * 0.20780632) - 12.12948) * ((x0 +...
# 	7  >>>>  0.210718  (x0 * ((x0 * 0.0014503103) + (x0 * (x0 * -1.35...
#
# 	       loss  complexity
# 	0  0.004184           1
# 	1  0.000517           5
# 	2  0.000255           7
# 	3  0.000063           9
# 	4  0.000063          11
# 	5  0.000012          14
# 	6  0.000010          16
# 	7  0.000002          23
# ]
# Model SymPy for 'f': x0*(x0*x0*(-1.3515511e-5) + x0*0.0014503103) + x0*(-0.8710277) - 0.17095427*x0 + x0 + 0.87266374
# Latex Equation for 'f': x_{0} \left(x_{0} x_{0} \left(-1.35 \cdot 10^{-5}\right) + x_{0} \cdot 0.00145\right) + x_{0} \left(-0.871\right) - x_{0} \cdot 0.171 + x_{0} + 0.873
#   - outputs\20260724_182746_eeOMdQ\hall_of_fame.csv

# %%
fx_fit =  x*(x*x*(-1.3515511e-5) + x*0.0014503103) + x*(-0.8710277) - 0.17095427*x + x + 0.87266374

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(44)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_BHpriori/BHmodel/DS2Bootstrap-results/bootstrap_004_seed_44/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
#           "exp",
#         "sin",
         "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="best",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
# #           "exp": 1
        "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {model.sympy()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           5.740e-03  0.000e+00  y = 0.57723
# 5           7.718e-04  5.016e-01  y = (x₀ * 0.0066241) + 0.38864
# 7           3.882e-04  3.436e-01  y = ((x₀ * x₀) * 0.00011743) + 0.46874
# 9           8.146e-05  7.807e-01  y = (((x₀ * 0.00034706) + -0.013543) * x₀) + 0.6422
# 11          8.137e-05  5.762e-04  y = (x₀ * (((x₀ * -0.99966) + x₀) + -0.013409)) + 0.64048
# 13          2.320e-06  1.779e+00  y = 0.92903 - (x₀ * ((x₀ * ((x₀ * 1.4467e-05) - 0.001609))...
#                                        + 0.047859))
# 15          2.319e-06  1.891e-04  y = 0.92902 - (x₀ * (((x₀ * ((x₀ * 1.4542e-05) - 0.001617)...
#                                       ) * 0.99521) + 0.04786))
# 17          2.220e-06  2.198e-02  y = ((x₀ * 1.8623) + 0.93877) - (x₀ * ((x₀ * ((1.4942e-05 ...
#                                       * x₀) - 0.0016507)) + 1.9113))
# 19          2.218e-06  2.511e-04  y = ((x₀ * 1.8621) + 0.93873) - ((((x₀ + 0.31849) * ((x₀ *...
#                                        1.491e-05) - 0.0016535)) + 1.9116) * x₀)
# 21          2.218e-06  1.234e-04  y = ((x₀ * 1.8621) + 0.93873) - (x₀ * (((x₀ + 0.31849) * (...
#                                       ((x₀ * 1.2838e-05) - 0.0014236) * 1.1616)) + 1.9116))
# 23          2.218e-06  6.146e-05  y = ((x₀ * 1.8621) + 0.93873) - (x₀ * ((((x₀ * 1.2851e-05)...
#                                        - 0.0014242) * (((x₀ - 0.0067661) + 0.31849) * 1.1616)) +...
#                                        1.9116))
# 29          2.146e-06  5.441e-03  y = ((x₀ * 1.8622) + 0.93949) - (((((((x₀ * 9.3077e-06) - ...
#                                       0.0010483) * (x₀ - (x₀ * 0.015873))) * (1.4093 - (x₀ * 0.0...
#                                       0060462))) * 1.148) + 1.9114) * x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Model for 'f': PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          0.5772316
# 	1         0.501626                   (x0 * 0.0066240644) + 0.38863602
# 	2         0.343580           ((x0 * x0) * 0.00011743383) + 0.46874112
# 	3         0.780713  (((x0 * 0.00034705544) + -0.013543256) * x0) +...
# 	4         0.000576  (x0 * (((x0 * -0.9996552) + x0) + -0.013409442...
# 	5   >>>>  1.778684  0.92902505 - (x0 * ((x0 * ((x0 * 1.446724e-5) ...
# 	6         0.000189  0.92902464 - (x0 * (((x0 * ((x0 * 1.4542445e-5...
# 	7         0.021976  ((x0 * 1.8623099) + 0.9387681) - (x0 * ((x0 * ...
# 	8         0.000251  ((x0 * 1.862065) + 0.93873173) - ((((x0 + 0.31...
# 	9         0.000123  ((x0 * 1.862065) + 0.93873173) - (x0 * (((x0 +...
# 	10        0.000061  ((x0 * 1.862065) + 0.93873173) - (x0 * ((((x0 ...
# 	11        0.005441  ((x0 * 1.8622028) + 0.939492) - (((((((x0 * 9....
#
# 	        loss  complexity
# 	0   0.005740           1
# 	1   0.000772           5
# 	2   0.000388           7
# 	3   0.000081           9
# 	4   0.000081          11
# 	5   0.000002          13
# 	6   0.000002          15
# 	7   0.000002          17
# 	8   0.000002          19
# 	9   0.000002          21
# 	10  0.000002          23
# 	11  0.000002          29
# ]
# Model SymPy for 'f': 0.92902505 - x0*(x0*(x0*1.446724e-5 - 1*0.0016090373) + 0.047858562)
# Latex Equation for 'f': 0.929 - x_{0} \left(x_{0} \left(x_{0} \cdot 1.45 \cdot 10^{-5} - 0.00161\right) + 0.0479\right)
#   - outputs\20260724_183334_EAXsrV\hall_of_fame.csv

# %%
fx_fit = 0.92902505 - x*(x*(x*1.446724e-5 - 1*0.0016090373) + 0.047858562)

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(45)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_BHpriori/BHmodel/DS2Bootstrap-results/bootstrap_005_seed_45/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
#           "exp",
#         "sin",
         "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="best",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
# #           "exp": 1
        "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {model.sympy()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.776e-03  0.000e+00  y = 0.58235
# 5           8.657e-04  5.144e-01  y = 0.37656 - (x₀ * -0.007249)
# 7           4.227e-04  3.584e-01  y = 0.4642 - ((x₀ * x₀) * -0.00012865)
# 9           8.859e-05  7.813e-01  y = 0.64259 - (((x₀ - 38.152) * x₀) * -0.00036584)
# 11          8.855e-05  2.486e-04  y = 0.6609 - ((x₀ - -1.1198) * ((x₀ * -0.00036839) + 0.014...
#                                       524))
# 13          8.854e-05  6.175e-05  y = (((x₀ * 0.98586) - (x₀ * (x₀ * -0.00036888))) + 0.6450...
#                                       1) - x₀
# 15          8.822e-05  1.799e-03  y = ((0.98566 - x₀) * x₀) + ((0.64748 - (x₀ * (x₀ * -1.000...
#                                       4))) - x₀)
# 19          3.845e-05  2.076e-01  y = 0.74527 - (((x₀ - 44.948) + 0.0043796) * ((x₀ * -0.000...
#                                       4475) + ((x₀ - 25.716) * (x₀ * 5.7736e-06))))
# 24          2.211e-06  5.712e-01  y = 0.7942 - ((x₀ + (x₀ * (-0.94986 - (((square(x₀) * -1.5...
#                                       201e-05) + (x₀ + x₀)) - (x₀ * 1.9983))))) + -0.15143)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Model for 'f': PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                         0.58234745
# 	1        0.514414                    0.37655944 - (x0 * -0.00724896)
# 	2        0.358403           0.4641971 - ((x0 * x0) * -0.00012864803)
# 	3        0.781345  0.6425905 - (((x0 - 38.151573) * x0) * -0.0003...
# 	4        0.000249  0.66089886 - ((x0 - -1.119787) * ((x0 * -0.000...
# 	5        0.000062  (((x0 * 0.9858591) - (x0 * (x0 * -0.000368879)...
# 	6        0.001799  ((0.9856612 - x0) * x0) + ((0.64748234 - (x0 *...
# 	7        0.207636  0.7452707 - (((x0 - 44.947624) + 0.0043796166)...
# 	8  >>>>  0.571159  0.7941991 - ((x0 + (x0 * (-0.94985867 - (((squ...
#
# 	       loss  complexity
# 	0  0.006776           1
# 	1  0.000866           5
# 	2  0.000423           7
# 	3  0.000089           9
# 	4  0.000089          11
# 	5  0.000089          13
# 	6  0.000088          15
# 	7  0.000038          19
# 	8  0.000002          24
# ]
# Model SymPy for 'f': 0.7941991 - (x0*(-(x0**2*(-1.5201186e-5) - 1.9983062*x0 + x0 + x0) - 0.94985867) + x0 - 0.1514293)
# Latex Equation for 'f': 0.794 - \left(x_{0} \left(- (x_{0}^{2} \left(-1.52 \cdot 10^{-5}\right) - x_{0} \cdot 2.00 + x_{0} + x_{0}) - 0.950\right) + x_{0} - 0.151\right)
#   - outputs\20260724_184031_LVyS7T\hall_of_fame.csv

# %%
fx_fit =0.7941991 - (x*(-(x**2*(-1.5201186e-5) - 1.9983062*x + x + x) - 0.94985867) + x - 0.1514293)

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(46)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_BHpriori/BHmodel/DS2Bootstrap-results/bootstrap_006_seed_46/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
#           "exp",
#         "sin",
         "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="best",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
# #           "exp": 1
        "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {model.sympy()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.334e-03  0.000e+00  y = 0.58151
# 5           1.051e-03  4.857e-01  y = (x₀ * 0.0073674) + 0.37399
# 7           5.328e-04  3.396e-01  y = ((x₀ * x₀) * 0.00013095) - -0.46245
# 9           9.867e-05  8.431e-01  y = (((x₀ * 0.00039684) - 0.015684) * x₀) + 0.66251
# 11          9.866e-05  4.244e-05  y = (((0.98432 - (x₀ * -0.00039682)) * x₀) + 0.6625) - x₀
# 13          2.215e-06  1.898e+00  y = (x₀ * ((((x₀ * -1.5797e-05) - -0.0017824) * x₀) + -0.0...
#                                       53529)) - -0.97952
# 15          2.215e-06  7.600e-06  y = (x₀ * ((x₀ * (((x₀ + -1.0671e-06) * -1.5797e-05) - -0....
#                                       0017824)) + -0.053529)) - -0.97952
# 17          2.215e-06  5.335e-06  y = (x₀ * (((((x₀ + (x₀ * -1.3357e-08)) * -1.5797e-05) - -...
#                                       0.0017824) * x₀) + -0.053529)) - -0.97952
# 22          2.215e-06  9.894e-07  y = (x₀ * ((x₀ * (((((x₀ - square(x₀)) * 1.8102e-08) + x₀)...
#                                        * -1.5797e-05) - -0.0017824)) + -0.053529)) - -0.97952
# 25          2.215e-06  7.153e-07  y = (x₀ * ((x₀ * (((x₀ + (x₀ * ((7.4625e-06 * ((0.30089 * ...
#                                       x₀) * x₀)) * -0.0017824))) * -1.5797e-05) - -0.0017824)) +...
#                                        -0.053529)) - -0.97952
# 29          2.215e-06  3.278e-07  y = (x₀ * ((x₀ * (((x₀ + (x₀ * ((((7.4625e-06 * x₀) * ((-1...
#                                       .3609 * x₀) * -1.3609)) * 0.2923) * -0.0017824))) * -1.579...
#                                       7e-05) - -0.0017824)) + -0.053529)) - -0.97952
# 30          2.215e-06  1.353e-05  y = (x₀ * ((x₀ * (((x₀ + ((x₀ * (7.4625e-06 * ((x₀ * (7.46...
#                                       25e-06 + x₀)) * square(-0.67074)))) * -0.0017824)) * -1.57...
#                                       97e-05) - -0.0017824)) + -0.053529)) - -0.97952
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   - outputs\20260724_184517_yDjdhD\hall_of_fame.csv
# Model for 'f': PySRRegressor.equations_ = [
# 	    pick         score                                           equation  \
# 	0         0.000000e+00                                          0.5815084
# 	1         4.857346e-01                   (x0 * 0.0073674284) + 0.37398607
# 	2         3.396075e-01           ((x0 * x0) * 0.00013094654) - -0.4624532
# 	3         8.431484e-01  (((x0 * 0.00039683888) - 0.015684282) * x0) + ...
# 	4         4.241601e-05  (((0.98431593 - (x0 * -0.00039682083)) * x0) +...
# 	5   >>>>  1.898128e+00  (x0 * ((((x0 * -1.5796753e-5) - -0.0017824314)...
# 	6         7.605867e-06  (x0 * ((x0 * (((x0 + -1.0671199e-6) * -1.57966...
# 	7         5.326432e-06  (x0 * (((((x0 + (x0 * -1.3357162e-8)) * -1.579...
# 	8         9.840435e-07  (x0 * ((x0 * (((((x0 - square(x0)) * 1.8102297...
# 	9         7.222363e-07  (x0 * ((x0 * (((x0 + (x0 * ((7.4625377e-6 * ((...
# 	10        3.385489e-07  (x0 * ((x0 * (((x0 + (x0 * ((((7.4625377e-6 * ...
# 	11        1.354206e-05  (x0 * ((x0 * (((x0 + ((x0 * (7.4625377e-6 * ((...
#
# 	        loss  complexity
# 	0   0.007334           1
# 	1   0.001051           5
# 	2   0.000533           7
# 	3   0.000099           9
# 	4   0.000099          11
# 	5   0.000002          13
# 	6   0.000002          15
# 	7   0.000002          17
# 	8   0.000002          22
# 	9   0.000002          25
# 	10  0.000002          29
# 	11  0.000002          30
# ]
# Model SymPy for 'f': x0*(x0*(x0*(-1.5796753e-5) - 1*(-0.0017824314)) - 0.053529017) - 1*(-0.9795196)
# Latex Equation for 'f': x_{0} \left(x_{0} \left(x_{0} \left(-1.58 \cdot 10^{-5}\right) - -0.00178\right) - 0.0535\right) - -0.979

# %%
fx_fit = x*(x*(x*(-1.5796753e-5) - 1*(-0.0017824314)) - 0.053529017) - 1*(-0.9795196)

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(47)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_BHpriori/BHmodel/DS2Bootstrap-results/bootstrap_007_seed_47/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
#           "exp",
#         "sin",
         "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="best",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
# #           "exp": 1
        "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {model.sympy()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.466e-03  0.000e+00  y = 0.58284
# 5           8.804e-04  4.985e-01  y = (x₀ * 0.0070139) - -0.38392
# 7           4.390e-04  3.479e-01  y = (x₀ * (x₀ * 0.00012521)) + 0.46791
# 9           9.380e-05  7.717e-01  y = 0.64696 - (x₀ * (0.01409 - (x₀ * 0.0003655)))
# 11          9.379e-05  3.427e-05  y = (((x₀ * 0.00036543) - 1.0141) * x₀) + (0.64691 + x₀)
# 15          1.197e-05  5.147e-01  y = ((0.039113 - (x₀ * 0.00064584)) * ((x₀ * (x₀ * 0.01651...
#                                       )) - x₀)) + 0.85407
# 19          2.454e-06  3.961e-01  y = (x₀ * (-0.050782 - (x₀ * -0.0017244))) - (((x₀ * ((-0....
#                                       0061962 - x₀) * x₀)) * -1.5665e-05) - 0.95086)
# 21          2.424e-06  6.238e-03  y = ((x₀ * ((-0.051325 - x₀) * 0.99826)) - ((((x₀ * x₀) * ...
#                                       x₀) * 1.5869e-05) - 0.95454)) + (x₀ * x₀)
# 25          2.420e-06  4.008e-04  y = ((x₀ * ((-0.051325 - x₀) * 0.99826)) - (((((x₀ * (x₀ *...
#                                        x₀)) + 0.23626) - -0.32005) * 1.5869e-05) - 0.95454)) + (...
#                                       x₀ * x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   - outputs\20260724_184939_UktNdy\hall_of_fame.csv
# Model for 'f': PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                           0.582845
# 	1        0.498495                   (x0 * 0.007013877) - -0.38391575
# 	2        0.347901           (x0 * (x0 * 0.00012520947)) + 0.46790725
# 	3        0.771726  0.646964 - (x0 * (0.014090369 - (x0 * 0.000365...
# 	4        0.000034  (((x0 * 0.00036542854) - 1.0140862) * x0) + (0...
# 	5        0.514719  ((0.039113414 - (x0 * 0.00064583705)) * ((x0 *...
# 	6  >>>>  0.396101  (x0 * (-0.05078155 - (x0 * -0.0017243768))) - ...
# 	7        0.006238  ((x0 * ((-0.05132549 - x0) * 0.9982584)) - (((...
# 	8        0.000401  ((x0 * ((-0.05132549 - x0) * 0.9982584)) - (((...
#
# 	       loss  complexity
# 	0  0.006466           1
# 	1  0.000880           5
# 	2  0.000439           7
# 	3  0.000094           9
# 	4  0.000094          11
# 	5  0.000012          15
# 	6  0.000002          19
# 	7  0.000002          21
# 	8  0.000002          25
# ]
# Model SymPy for 'f': x0*(-(-0.0017243768)*x0 - 0.05078155) - (x0*(-x0 - 0.006196212)*x0*(-1.5665179e-5) - 1*0.95085657)
# Latex Equation for 'f': x_{0} \left(- \left(-0.00172\right) x_{0} - 0.0508\right) - \left(x_{0} \left(- x_{0} - 0.00620\right) x_{0} \left(-1.57 \cdot 10^{-5}\right) - 0.951\right)

# %%
fx_fit = x*(-(-0.0017243768)*x - 0.05078155) - (x*(-x - 0.006196212)*x*(-1.5665179e-5) - 1*0.95085657)

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(48)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_BHpriori/BHmodel/DS2Bootstrap-results/bootstrap_008_seed_48/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
#           "exp",
#         "sin",
         "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="best",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
# #           "exp": 1
        "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {model.sympy()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.871e-03  0.000e+00  y = 0.5826
# 5           1.078e-03  4.630e-01  y = (x₀ * 0.0070158) - -0.38446
# 7           5.614e-04  3.264e-01  y = (x₀ * (x₀ * 0.00012502)) + 0.46816
# 9           1.089e-04  8.202e-01  y = (x₀ * ((x₀ * 0.00038802) - 0.015527)) + 0.66594
# 11          1.088e-04  6.864e-05  y = (((x₀ * 0.00038791) - 1.0155) * x₀) - (-0.66587 - x₀)
# 13          1.088e-04  3.448e-05  y = (((x₀ * ((x₀ * 0.00038784) - -1.9845)) - -0.6658) - x₀...
#                                       ) - x₀
# 14          1.085e-04  3.047e-03  y = ((x₀ * (-0.015457 - (x₀ * -1.0004))) + 0.66511) - squa...
#                                       re(x₀)
# 15          3.589e-06  3.409e+00  y = (x₀ * -0.049487) - ((x₀ * (x₀ * (-0.0016389 - (x₀ * -1...
#                                       .4312e-05)))) + -0.94789)
# 17          2.660e-06  1.498e-01  y = x₀ + ((x₀ * -1.0531) - (((x₀ * x₀) * (-0.0017676 - (x₀...
#                                        * -1.5743e-05))) + -0.97888))
# 21          2.660e-06  2.659e-05  y = ((x₀ * -1.0531) - (((-0.0017674 - (((x₀ * -1.0529) - x...
#                                       ₀) * 7.6667e-06)) * (x₀ * x₀)) + -0.97895)) + x₀
# 23          2.653e-06  1.299e-03  y = ((x₀ * (x₀ - 1.8146)) - (((x₀ * (0.99823 - ((x₀ + 1.15...
#                                       03) * -1.5729e-05))) * (x₀ - 0.76299)) + -0.97723)) + x₀
# 25          2.600e-06  1.006e-02  y = (((x₀ - 1.8147) * x₀) - (((x₀ * (0.99813 - ((-6.299 - ...
#                                       (x₀ + 1.1503)) * 1.5709e-05))) * (x₀ - 0.76314)) + -0.9772...
#                                       )) + x₀
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   - outputs\20260724_185316_0uCsKd\hall_of_fame.csv
# Model for 'f': PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                         0.58260435
# 	1         0.462953                   (x0 * 0.0070157577) - -0.3844647
# 	2         0.326383           (x0 * (x0 * 0.00012502472)) + 0.46816358
# 	3         0.820236  (x0 * ((x0 * 0.00038802065) - 0.015526587)) + ...
# 	4         0.000069  (((x0 * 0.00038791148) - 1.0155203) * x0) - (-...
# 	5         0.000034  (((x0 * ((x0 * 0.00038784163) - -1.9844842)) -...
# 	6         0.003047  ((x0 * (-0.0154572595 - (x0 * -1.0003867))) + ...
# 	7   >>>>  3.408925  (x0 * -0.049487345) - ((x0 * (x0 * (-0.0016389...
# 	8         0.149772  x0 + ((x0 * -1.0530959) - (((x0 * x0) * (-0.00...
# 	9         0.000027  ((x0 * -1.0530975) - (((-0.0017673965 - (((x0 ...
# 	10        0.001299  ((x0 * (x0 - 1.8146069)) - (((x0 * (0.9982294 ...
# 	11        0.010058  (((x0 - 1.8147475) * x0) - (((x0 * (0.9981316 ...
#
# 	        loss  complexity
# 	0   0.006871           1
# 	1   0.001078           5
# 	2   0.000561           7
# 	3   0.000109           9
# 	4   0.000109          11
# 	5   0.000109          13
# 	6   0.000109          14
# 	7   0.000004          15
# 	8   0.000003          17
# 	9   0.000003          21
# 	10  0.000003          23
# 	11  0.000003          25
# ]
# Model SymPy for 'f': x0*(-0.049487345) - (x0*x0*(-(-1.4311597e-5)*x0 - 0.0016389234) - 0.94789064)
# Latex Equation for 'f': x_{0} \left(-0.0495\right) - \left(x_{0} x_{0} \left(- \left(-1.43 \cdot 10^{-5}\right) x_{0} - 0.00164\right) - 0.948\right)

# %%
fx_fit = x*(-0.049487345) - (x*x*(-(-1.4311597e-5)*x - 0.0016389234) - 0.94789064)

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(49)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_BHpriori/BHmodel/DS2Bootstrap-results/bootstrap_009_seed_49/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
#           "exp",
#         "sin",
         "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="best",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
# #           "exp": 1
        "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {model.sympy()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           7.848e-03  0.000e+00  y = 0.5853
# 5           1.113e-03  4.884e-01  y = (x₀ * 0.0075815) + 0.37172
# 7           5.551e-04  3.476e-01  y = ((x₀ * x₀) * 0.00013463) + 0.46268
# 9           1.014e-04  8.502e-01  y = (((x₀ * 0.00040146) + -0.015759) * x₀) + 0.6636
# 11          1.014e-04  6.003e-05  y = (x₀ + 0.66359) + (((x₀ * 0.00040138) + -1.0158) * x₀)
# 13          1.014e-04  4.268e-05  y = ((x₀ * ((x₀ * 0.00040145) + -1.0158)) - -0.58237) + (x...
#                                       ₀ + 0.081233)
# 15          2.190e-06  1.917e+00  y = (x₀ * -0.053754) + ((((x₀ * -1.5803e-05) + 0.0017907) ...
#                                       * (x₀ * x₀)) + 0.98183)
# 17          2.169e-06  4.910e-03  y = (x₀ * -0.053412) + (((x₀ * (((x₀ * -1.5664e-05) + 0.00...
#                                       17783) * x₀)) + 0.9819) - 0.0029846)
# 25          2.118e-06  2.973e-03  y = ((x₀ + (((x₀ * -1.5783e-05) + 0.0018104) * (x₀ * (x₀ +...
#                                        ((x₀ + (x₀ * x₀)) * -0.00030611))))) + 0.9827) + (x₀ * -1...
#                                       .054)
# 29          2.093e-06  2.867e-03  y = ((x₀ + ((((x₀ * -1.5757e-05) + 0.0018199) * ((x₀ + x₀)...
#                                        - x₀)) * (x₀ + ((x₀ + (x₀ * x₀)) * -0.00046904)))) + 0.98...
#                                       276) + (x₀ * -1.0541)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Model for 'f': PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                          0.5852995
# 	1        0.488367                    (x0 * 0.007581471) + 0.37172315
# 	2        0.347647            ((x0 * x0) * 0.00013463001) + 0.4626823
# 	3        0.850191  (((x0 * 0.00040146062) + -0.015759002) * x0) +...
# 	4        0.000060  (x0 + 0.66358846) + (((x0 * 0.00040138437) + -...
# 	5        0.000043  ((x0 * ((x0 * 0.00040145096) + -1.0157585)) - ...
# 	6  >>>>  1.917366  (x0 * -0.05375446) + ((((x0 * -1.5802892e-5) +...
# 	7        0.004910  (x0 * -0.053411514) + (((x0 * (((x0 * -1.56638...
# 	8        0.002973  ((x0 + (((x0 * -1.5783016e-5) + 0.0018103915) ...
# 	9        0.002867  ((x0 + ((((x0 * -1.5757496e-5) + 0.0018198633)...
#
# 	       loss  complexity
# 	0  0.007848           1
# 	1  0.001113           5
# 	2  0.000555           7
# 	3  0.000101           9
# 	4  0.000101          11
# 	5  0.000101          13
# 	6  0.000002          15
# 	7  0.000002          17
# 	8  0.000002          25
# 	9  0.000002          29
# ]
# Model SymPy for 'f': x0*x0*(0.0017906758 + x0*(-1.5802892e-5)) + x0*(-0.05375446) + 0.9818284
# Latex Equation for 'f': x_{0} x_{0} \cdot \left(0.00179 + x_{0} \left(-1.58 \cdot 10^{-5}\right)\right) + x_{0} \left(-0.0538\right) + 0.982
#   - outputs\20260724_185735_U0BiUs\hall_of_fame.csv

# %%
fx_fit = x*x*(0.0017906758 + x*(-1.5802892e-5)) + x*(-0.05375446) + 0.9818284

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()

# %% [markdown]
# ### seed(50)

# %%
from pysr import PySRRegressor
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
# np.random.seed(42)

df = pd.read_csv('D:/py_code/EEINN_BHpriori/BHmodel/DS2Bootstrap-results/bootstrap_010_seed_50/prediction.csv')

model = PySRRegressor(
    niterations= 30,  # < Increase me for better results
    populations= 30,
    binary_operators=["*", "+", "-"],
    unary_operators=[
#         "cos",
#           "exp",
#         "sin",
         "square", 
#         "cube", 
#         "inv(x) = 1/x",
    ],
#      extra_sympy_mappings={"myfunction": lambda x: x**3},
#     loss="L1DistLoss()",
    model_selection="best",
    complexity_of_operators={
# # #         "sin": 3, 
# # #         "cos": 3,
# #           "exp": 1
        "square": 3,
#         "cube": 3
   },
    early_stop_condition=(
        "stop_if(loss, complexity) = loss < 1e-10 && complexity < 20"
    ),
)


x = df['xstable'].to_numpy().reshape(-1, 1)
f = df['hx'].to_numpy().reshape(-1, 1)

model.fit(x,f)

print(f"Model for 'f': {model}")
print(f"Model SymPy for 'f': {model.sympy()}")
print(f"Latex Equation for 'f': {model.latex()}")
# Out:
# E:\Anaconda3\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.993e-03  0.000e+00  y = 0.58397
# 5           8.005e-04  5.419e-01  y = 0.37213 - (x₀ * -0.0073797)
# 7           3.739e-04  3.806e-01  y = (x₀ * (x₀ * 0.00012967)) + 0.46237
# 9           9.645e-05  6.775e-01  y = (((x₀ + -37.742) * x₀) * 0.00035599) + 0.63583
# 11          9.558e-05  4.534e-03  y = ((x₀ + -82.657) * ((x₀ * 0.00034461) + 0.015742)) + 1....
#                                       9278
# 13          4.250e-05  4.052e-01  y = ((x₀ * (x₀ + -106.5)) * ((x₀ + -45.192) * -5.5864e-06)...
#                                       ) + 0.74865
# 17          1.518e-05  2.573e-01  y = (((x₀ + -53.432) * ((x₀ * ((-49.624 + x₀) * -0.053803)...
#                                       ) + x₀)) * 0.00018764) + 0.82746
# 21          3.018e-06  4.039e-01  y = ((x₀ + (((x₀ + -50.948) * -0.041753) * ((x₀ + -22.503)...
#                                        + x₀))) * ((x₀ + -35.797) * 0.00018794)) + 0.62462
# 23          2.943e-06  1.258e-02  y = 0.62759 + (((x₀ + ((((x₀ + 0.00018534) + -50.948) * -0...
#                                       .042511) * ((x₀ + x₀) + -22.03))) * (x₀ + -36.014)) * 0.00...
#                                       018534)
# 25          2.943e-06  3.040e-06  y = ((((x₀ + -36.014) - (x₀ - x₀)) * ((((x₀ + -50.948) * -...
#                                       0.042511) * (x₀ + (x₀ + -22.03))) + x₀)) * 0.00018534) + 0...
#                                       .62759
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Model for 'f': PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                          0.5839689
# 	1        0.541876                  0.37212908 - (x0 * -0.0073797014)
# 	2        0.380557            (x0 * (x0 * 0.00012967452)) + 0.4623686
# 	3        0.677541  (((x0 + -37.74215) * x0) * 0.00035599034) + 0....
# 	4        0.004534  ((x0 + -82.65681) * ((x0 * 0.00034460996) + 0....
# 	5        0.405218  ((x0 * (x0 + -106.500435)) * ((x0 + -45.192245...
# 	6        0.257327  (((x0 + -53.431934) * ((x0 * ((-49.623814 + x0...
# 	7  >>>>  0.403882  ((x0 + (((x0 + -50.948296) * -0.041753057) * (...
# 	8        0.012584  0.62758976 + (((x0 + ((((x0 + 0.0001853374) + ...
# 	9        0.000003  ((((x0 + -36.013733) - (x0 - x0)) * ((((x0 + -...
#
# 	       loss  complexity
# 	0  0.006993           1
# 	1  0.000800           5
# 	2  0.000374           7
# 	3  0.000096           9
# 	4  0.000096          11
# 	5  0.000043          13
# 	6  0.000015          17
# 	7  0.000003          21
# 	8  0.000003          23
# 	9  0.000003          25
# ]
# Model SymPy for 'f': (x0 + (x0 - 50.948296)*(-0.041753057)*(x0 + x0 - 22.502914))*(x0 - 35.7972)*0.00018794382 + 0.62462354
# Latex Equation for 'f': \left(x_{0} + \left(x_{0} - 50.9\right) \left(-0.0418\right) \left(x_{0} + x_{0} - 22.5\right)\right) \left(x_{0} - 35.8\right) 0.000188 + 0.625
#   - outputs\20260724_190126_a7jtRq\hall_of_fame.csv

# %%
fx_fit = (x + (x - 50.948296)*(-0.041753057)*(x + x - 22.502914))*(x - 35.7972)*0.00018794382 + 0.62462354

plt.subplot(211)
plt.plot(x,f,'b.',markersize=2, label='data')
plt.plot(x,fx_fit,'r-',label='fitting')
plt.legend()
